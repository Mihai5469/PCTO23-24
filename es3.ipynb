# %% [markdown]
# <a href="https://colab.research.google.com/github/Mihai5469/PCTO23-24/blob/main/es3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# iporto librerie necesarie

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# apro il file csv

# %%
file_patch = 'pub.csv'

dati = pd.read_csv(file_patch)

# %%
dati
# Out:
#         TV  Radio  Newspaper  Sales
# 0    230.1   37.8       69.2   22.1
# 1     44.5   39.3       45.1   10.4
# 2     17.2   45.9       69.3   12.0
# 3    151.5   41.3       58.5   16.5
# 4    180.8   10.8       58.4   17.9
# ..     ...    ...        ...    ...
# 195   38.2    3.7       13.8    7.6
# 196   94.2    4.9        8.1   14.0
# 197  177.0    9.3        6.4   14.8
# 198  283.6   42.0       66.2   25.5
# 199  232.1    8.6        8.7   18.4
#
# [200 rows x 4 columns]

# %% [markdown]
# elimino dati non necesari

# %%
dati = dati.drop(columns= ['Radio', 'Newspaper'], axis = 1)

# %%
dati.head()
# Out:
#       TV  Sales
# 0  230.1   22.1
# 1   44.5   10.4
# 2   17.2   12.0
# 3  151.5   16.5
# 4  180.8   17.9

# %%
from sklearn.linear_model import LinearRegression #lib per i grafici

# %%
X = dati[['TV']]
y = dati['Sales']

regression_model = LinearRegression()

regression_model.fit(X, y)

plt.scatter(X, y, color = "blue", label = 'Dati esservati')
plt.plot(X, regression_model.predict(X), color = "red", linewidth = 2, label ="Regresione lineare")

plt.xlabel("TV")
plt.ylabel("Vendite")
plt.legend()
plt.show()

# %%
nuovi_dati = pd.DataFrame({'TV' : [249]})

previsioni = regression_model.predict(nuovi_dati)

# %%
print(previsioni)
# Out:
# [20.78554934]
